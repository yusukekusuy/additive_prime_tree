# %%
import signal
import math
from function.function3 import check_loop
from function.candidates_primitive_sets import cand_primitive_set
from function.primitive_sets import p5, p6, p7, p8, p9, p10


# === タイムアウト用のハンドラー ===
class TimeoutException(Exception):
    pass

def timeout_handler(signum, frame):
    raise TimeoutException


# === ソート処理 ===
pair6 = p6()
pair6_sorted = sorted(pair6, key=lambda L: math.prod(L))

pair7 = p7() + cand_primitive_set()
pair7_sorted = sorted(pair7, key=lambda L: math.prod(L))

pairs = p5() + pair6_sorted + pair7_sorted

for pair in pairs:
    print(pair)

limit = 1000

# === 10分 (600秒) タイムアウト ===
TIME_LIMIT = 600
signal.signal(signal.SIGALRM, timeout_handler)

for pair in pairs:
    print(f"Now checking: {pair}")

    signal.alarm(TIME_LIMIT)   # ⚡ タイマー開始
    try:
        result = check_loop(pair, limit)
        signal.alarm(0)        # タイマー停止

        print(result)          # 成功時の結果表示

    except TimeoutException:
        print(f"  → ❌ {pair} は {TIME_LIMIT} 秒を超えたためスキップしました")
        signal.alarm(0)        # 念のため解除
# Out:
# [2, 3, 5, 7, 19]
# [2, 3, 5, 13, 17]
# [2, 3, 5, 7, 11, 13]
# [2, 3, 5, 7, 11, 23]
# [2, 3, 5, 7, 13, 29]
# [2, 3, 5, 11, 13, 23]
# [2, 3, 7, 11, 13, 23]
# [2, 3, 5, 11, 19, 31]
# [2, 3, 5, 7, 29, 41]
# [2, 3, 5, 11, 13, 97]
# [2, 5, 7, 11, 13, 43]
# [2, 3, 5, 7, 37, 59]
# [2, 3, 5, 11, 29, 53]
# [2, 3, 5, 7, 11, 223]
# [2, 3, 5, 17, 19, 89]
# [2, 3, 5, 7, 41, 103]
# [2, 3, 7, 17, 31, 41]
# [2, 3, 5, 11, 31, 107]
# [2, 3, 5, 11, 59, 61]
# [2, 3, 5, 23, 31, 61]
# [2, 3, 5, 7, 97, 113]
# [2, 3, 5, 17, 67, 79]
# [2, 3, 5, 7, 11, 1499]
# [2, 3, 5, 29, 41, 103]
# [2, 5, 7, 31, 37, 59]
# [2, 3, 5, 7, 149, 229]
# [2, 3, 5, 67, 71, 103]
# [2, 3, 29, 41, 43, 53]
# [2, 3, 5, 101, 257, 337]
# [2, 3, 5, 7, 11, 17, 29]
# [2, 3, 7, 11, 13, 17, 31]
# [2, 3, 5, 7, 11, 29, 67]
# [3, 5, 7, 11, 13, 17, 23]
# [2, 5, 7, 13, 17, 23, 29]
# [2, 5, 7, 11, 13, 29, 41]
# [2, 3, 7, 13, 19, 23, 53]
# [2, 3, 11, 13, 17, 31, 37]
# [2, 5, 7, 11, 19, 29, 41]
# [2, 5, 7, 11, 13, 17, 107]
# [2, 5, 7, 13, 19, 23, 53]
# [2, 3, 7, 11, 17, 37, 73]
# [2, 3, 7, 13, 19, 43, 53]
# [2, 3, 7, 13, 31, 37, 41]
# [2, 3, 7, 13, 17, 47, 59]
# [2, 3, 11, 17, 19, 23, 53]
# [2, 3, 7, 11, 17, 31, 107]
# [2, 3, 7, 11, 17, 59, 61]
# [2, 5, 7, 13, 17, 37, 53]
# [2, 3, 7, 17, 19, 43, 53]
# [2, 3, 7, 11, 23, 29, 103]
# [2, 5, 7, 11, 19, 31, 71]
# [2, 3, 11, 13, 19, 43, 53]
# [2, 5, 7, 17, 23, 31, 47]
# [2, 3, 7, 13, 23, 47, 73]
# [2, 3, 7, 17, 23, 41, 67]
# [2, 3, 7, 11, 13, 67, 113]
# [2, 3, 11, 17, 19, 43, 53]
# [3, 7, 11, 17, 19, 23, 29]
# [2, 3, 7, 11, 13, 29, 317]
# [3, 5, 7, 13, 17, 47, 53]
# [2, 3, 7, 13, 31, 41, 89]
# [2, 7, 11, 13, 17, 31, 59]
# [2, 3, 7, 23, 29, 43, 53]
# [2, 3, 7, 17, 37, 41, 59]
# [2, 3, 7, 11, 29, 47, 103]
# [2, 3, 7, 11, 43, 53, 67]
# [2, 5, 7, 17, 19, 37, 89]
# [2, 5, 7, 19, 23, 43, 59]
# [3, 5, 11, 13, 23, 37, 47]
# [2, 3, 17, 19, 23, 41, 53]
# [2, 11, 13, 17, 23, 29, 31]
# [2, 3, 17, 19, 31, 41, 43]
# [2, 3, 7, 17, 43, 53, 67]
# [2, 3, 11, 13, 31, 41, 103]
# [2, 3, 7, 11, 47, 71, 73]
# [2, 7, 11, 13, 23, 37, 67]
# [2, 3, 7, 11, 17, 113, 137]
# [2, 3, 11, 13, 31, 67, 79]
# [2, 7, 11, 23, 29, 37, 41]
# [2, 3, 11, 17, 43, 53, 67]
# [2, 7, 11, 19, 31, 37, 53]
# [2, 5, 7, 11, 17, 73, 191]
# [2, 3, 7, 13, 47, 59, 127]
# [2, 5, 7, 11, 17, 113, 137]
# [2, 3, 13, 23, 41, 47, 79]
# [2, 3, 11, 17, 37, 61, 109]
# [2, 3, 11, 13, 37, 83, 109]
# [2, 3, 13, 17, 41, 73, 79]
# [2, 3, 7, 17, 61, 71, 109]
# [2, 3, 7, 11, 53, 103, 137]
# [2, 3, 11, 23, 41, 43, 131]
# [2, 3, 7, 11, 13, 97, 683]
# [2, 3, 7, 23, 71, 73, 97]
# [2, 3, 7, 11, 59, 73, 251]
# [2, 3, 11, 31, 41, 79, 89]
# [2, 3, 7, 11, 13, 223, 449]
# [2, 3, 13, 23, 59, 71, 83]
# [2, 3, 7, 11, 19, 223, 449]
# [2, 3, 19, 29, 43, 67, 101]
# [2, 5, 19, 37, 41, 43, 79]
# [2, 3, 7, 17, 53, 151, 173]
# [2, 3, 7, 13, 19, 241, 409]
# [2, 3, 7, 29, 31, 149, 199]
# [2, 3, 11, 37, 43, 109, 113]
# [2, 5, 11, 17, 47, 103, 149]
# [2, 5, 7, 11, 13, 293, 461]
# [2, 3, 19, 41, 53, 73, 79]
# [2, 3, 11, 37, 47, 59, 227]
# [2, 3, 13, 37, 47, 59, 227]
# [2, 3, 7, 29, 53, 103, 283]
# [2, 3, 7, 19, 113, 137, 197]
# [2, 13, 29, 37, 41, 43, 53]
# [2, 3, 11, 29, 53, 103, 283]
# [2, 3, 7, 59, 61, 149, 181]
# [2, 3, 7, 71, 73, 97, 241]
# [2, 5, 7, 23, 53, 131, 937]
# [2, 3, 31, 43, 71, 109, 191]
# [2, 3, 29, 43, 67, 113, 223]
# Now checking: [2, 3, 5, 7, 19]
# P = {2, 3, 5, 7, 19} is a primitive set, initial : (2,3273)[(2, 3)] RRRLLRRRLR  cycle_start : (180047,101481)[(7, 3)] LLRRRLR  cycle_end : (3591119,2026347)[(7, 3)] (cycle length = 7)
# Now checking: [2, 3, 5, 13, 17]
# P = {2, 3, 5, 13, 17} is a primitive set, initial : (2,333)[(2, 3)] RRRLRLRRLRRLRLRLLRLLR  cycle_start : (2982941,2181753)[(13, 3)] LRLRRLRRLRLRLLRLLR  cycle_end : (3491040761,2551226373)[(13, 3)] (cycle length = 18)
# Now checking: [2, 3, 5, 7, 11, 13]
# P = {2, 3, 5, 7, 11, 13} is a primitive set, initial : (26,1689)[(26, 3)] RRRLRLRRLRLLRLRLLRRLLRLRLRLLRLLRLRLLRRLLLRRLRRLLRRRRLLRRRLRLRLRLRLLLRLLLRRLLLRLRLRLRLRRRLRRRLLRRR  cycle_start : (236873062743266443286,69668547865664987515)[(26, 5)] LRLRLRLRLLLRLLLRRLLLRLRLRLRLRRRLRRRLLRRR  cycle_end : (2012279416625011686618578996,584688857042960622807993505)[(26, 5)] (cycle length = 40)
# Now checking: [2, 3, 5, 7, 11, 23]
# P = {2, 3, 5, 7, 11, 23} is a primitive set, initial : (2,51483)[(2, 3)] RRRLRLRRLLLLRRRRLLRLLLLRRRLLRRRLRLRRLRLRLLRLLRLRR  cycle_start : (21181476462651,8217636096926)[(3, 2)] LRLRLLRLLRLRR  cycle_end : (1756086953970687,2475499552)[(3, 2)] (cycle length = 13)
# Now checking: [2, 3, 5, 7, 13, 29]
# P = {2, 3, 5, 7, 13, 29} is a primitive set, initial : (2,36993)[(2, 3)] RRRLRLRRLRRLRRLLRRRRRRRRRLRLLRRLLLRLRLRRLRLRRLLRRLLRLLLLLLRLRRLLRRRLRLRLLRLRLLRRLLRRLR  cycle_start : (11995604824515213979,7027224418754109161)[(7, 29)] RRRRRLRLLRRLLLRLRLRRLRLRRLLRRLLRLLLLLLRLRRLLRRRLRLRLLRLRLLRRLLRRLR  cycle_end : (224946372887613108952962440461,224946372887613108950217755459)[(7, 29)] (cycle length = 66)
# Now checking: [2, 3, 5, 11, 13, 23]
# P = {2, 3, 5, 11, 13, 23} is a primitive set, initial : (2,63033)[(2, 3)] RRRLRRLRLRLRRL  cycle_start : (17838491,24646113)[(11, 3)] LRRLRLRLRRL  cycle_end : (2711261531,3746146143)[(11, 3)] (cycle length = 11)
# Now checking: [2, 3, 7, 11, 13, 23]
# P = {2, 3, 7, 11, 13, 23} is a primitive set, initial : (2,44259)[(2, 3)] RLRLLLRRLRR  cycle_start : (4293247,1593370)[(7, 2)] RLLLRRLRR  cycle_end : (171685619,63646280)[(7, 2)] (cycle length = 9)
# Now checking: [2, 3, 5, 11, 19, 31]
# P = {2, 3, 5, 11, 19, 31} is a primitive set, initial : (2,117483)[(2, 3)] RRRLRLRRLRRRRL  cycle_start : (22204391,26903733)[(11, 3)] LRLRRLRRRRL  cycle_end : (2042451521,2475025953)[(11, 3)] (cycle length = 11)
# Now checking: [2, 3, 5, 7, 29, 41]
# P = {2, 3, 5, 7, 29, 41} is a primitive set, initial : (2,148083)[(2, 3)] RRLRRRLLLRLRLRLLRRRLRLRL  cycle_start : (2650254391,4267032479)[(41, 29)] RRLLLRLRLRLLRRRLRLRL  cycle_end : (9129010085329,14698204731941)[(41, 29)] (cycle length = 20)
# Now checking: [2, 3, 5, 11, 13, 97]
# P = {2, 3, 5, 11, 13, 97} is a primitive set, initial : (2,414483)[(2, 3)] RRRLLRRLLLRRLLLRRLLRRRLL  cycle_start : (3606007202,8269362033)[(2, 3)] RRRLLRRLLLRRLLLRRLLRRRLL  cycle_end : (81142374059402,186077184052083)[(2, 3)] (cycle length = 24)
# Now checking: [2, 5, 7, 11, 13, 43]
# P = {2, 5, 7, 11, 13, 43} is a primitive set, initial : (104,39285)[(26, 5)] RLLRRRRLRLLLLL  cycle_start : (1141345,6336429)[(5, 11)] RRLRLLLLL  cycle_end : (33964835,189974807)[(5, 11)] (cycle length = 9)
# Now checking: [2, 3, 5, 7, 37, 59]
# P = {2, 3, 5, 7, 37, 59} is a primitive set, initial : (2,396813)[(2, 3)] RRRLLLLRRRRLLRLR  cycle_start : (190073723,119440899)[(7, 3)] LLLLRRRRLLRLR  cycle_end : (32311342469,20304556017)[(7, 3)] (cycle length = 13)
# Now checking: [2, 3, 5, 11, 29, 53]
# P = {2, 3, 5, 11, 29, 53} is a primitive set, initial : (2,38943)[(2, 3)] RRRLLRRLRRLLLLLRRLRLRRRRRLRRRRRLLRLRLLLLL  cycle_start : (38388677397,216032681126)[(3, 2)] RLLLLLRRLRLRRRRRLRRRRRLLRLRLLLLL  cycle_end : (2266974231605967,12762225030193406)[(3, 2)] (cycle length = 32)
# Now checking: [2, 3, 5, 7, 11, 223]
# P = {2, 3, 5, 7, 11, 223} is a primitive set, initial : (2,178533)[(2, 3)] RRLRRRRLRRRLLRRRLRLRLRLRLLLRLLLRRLLLRLRLRLRL  cycle_start : (12220993809529,19779546461741)[(223, 11)] RRRLRRRLLRRRLRLRLRLRLLLRLLLRRLLLRLRLRLRL  cycle_end : (98689623762947148499,159728090370553622291)[(223, 11)] (cycle length = 40)
# Now checking: [2, 3, 5, 17, 19, 89]
# P = {2, 3, 5, 17, 19, 89} is a primitive set, initial : (2,835623)[(2, 3)] RRLLRRLRRLRLLLRRLLRLLRLR  cycle_start : (25870913642,16395775083)[(2, 3)] RRLLRRLRRLRLLLRRLLRLLRLR  cycle_end : (838269343828082,531255903403743)[(2, 3)] (cycle length = 24)
# Now checking: [2, 3, 5, 7, 41, 103]
# P = {2, 3, 5, 7, 41, 103} is a primitive set, initial : (2,109953)[(2, 3)] RRLLRRRLLRRLRRLRRRRLLRRLLRLLRLLLL  cycle_start : (17706413553,83755014061)[(3, 41)] RRLLRRLRRLRRRRLLRRLLRLLRLLLL  cycle_end : (1858783881197157,1858863131602189)[(3, 41)] (cycle length = 28)
# Now checking: [2, 3, 7, 17, 31, 41]
# P = {2, 3, 7, 17, 31, 41} is a primitive set, initial : (2,628143)[(2, 3)] RLRRLLLRRRRL  cycle_start : (45854525,56532976)[(17, 2)] RLLLRRRRL  cycle_end : (1557169417,1920864896)[(17, 2)] (cycle length = 9)
# Now checking: [2, 3, 5, 11, 31, 107]
# P = {2, 3, 5, 11, 31, 107} is a primitive set, initial : (2,565293)[(2, 3)] RRRLRLRRLLLLLRRLRRRRLLRRRRRLLRLLL  cycle_start : (50575118155,186413462654)[(5, 2)] LRRLLLLLRRLRRRRLLRRRRRLLRLLL  cycle_end : (1638734974501255,1638815511780044)[(5, 2)] (cycle length = 28)
# Now checking: [2, 3, 5, 11, 59, 61]
# P = {2, 3, 5, 11, 59, 61} is a primitive set, initial : (2,151113)[(2, 3)] RLRLRRLRRRLLLL  cycle_start : (10124653,43218668)[(11, 2)] LRRLRRRLLLL  cycle_end : (627275143,2679255188)[(11, 2)] (cycle length = 11)
# Now checking: [2, 3, 5, 23, 31, 61]
# P = {2, 3, 5, 23, 31, 61} is a primitive set, initial : (2,83313)[(2, 3)] RRRLRRLRLLLLRRLLRLRRRRL  cycle_start : (595108601,724911093)[(23, 3)] LRRLRLLLLRRLLRLRRRRL  cycle_end : (2143580930861,2611129673673)[(23, 3)] (cycle length = 20)
# Now checking: [2, 3, 5, 7, 97, 113]
# P = {2, 3, 5, 7, 97, 113} is a primitive set, initial : (2,2195253)[(2, 3)] RRRLRLLRLRRLRLR  cycle_start : (1501553434,919811241)[(2, 3)] RRRLRLLRLRRLRLR  cycle_end : (915947594738,561082661757)[(2, 3)] (cycle length = 15)
# Now checking: [2, 3, 5, 17, 67, 79]
# P = {2, 3, 5, 17, 67, 79} is a primitive set, initial : (2,1687323)[(2, 3)] RRRLRRLRRLLLLLRLRRLL  cycle_start : (2063596685,4938795991)[(5, 67)] LLLLLRLRRLL  cycle_end : (82474687135,197526529787)[(5, 67)] (cycle length = 11)
# Now checking: [2, 3, 5, 7, 11, 1499]
# P = {2, 3, 5, 7, 11, 1499} is a primitive set, initial : (2,1104303)[(2, 3)] RRRLLRRRLRLRLLRLRRLRLR  cycle_start : (15400617748,9434065497)[(2, 3)] RRRLLRRRLRLRLLRLRRLRLR  cycle_end : (194016982389302,118850356026903)[(2, 3)] (cycle length = 22)
# Now checking: [2, 3, 5, 29, 41, 103]
# P = {2, 3, 5, 29, 41, 103} is a primitive set, initial : (2,2928873)[(2, 3)] RLRLRRRRLLRRLLRLLRLLLLRRLLRRLR  cycle_start : (689893392695,404260792532)[(5, 2)] RLRRRRLLRRLLRLLRLLLLRRLLRRLR  cycle_end : (72423628575406835,42438489472566548)[(5, 2)] (cycle length = 28)
# Now checking: [2, 5, 7, 31, 37, 59]
# P = {2, 5, 7, 31, 37, 59} is a primitive set, initial : (2,825725)[(2, 5)] RLLRLRLLRRRRLL  cycle_start : (104867259,233680585)[(7, 5)] LLRLRLLRRRRLL  cycle_end : (17826608303,39724873725)[(7, 5)] (cycle length = 13)
# Now checking: [2, 3, 5, 7, 149, 229]
# P = {2, 3, 5, 7, 149, 229} is a primitive set, initial : (2,1234083)[(2, 3)] RRRLRLLRLRLLRLLLLRLRRLRLRRLR  cycle_start : (192413372138,111564855957)[(2, 3)] RRRLRLLRLRLLRLLLLRLRRLRLRRLR  cycle_end : (25775310504862202,14945004973053723)[(2, 3)] (cycle length = 28)
# Now checking: [2, 3, 5, 67, 71, 103]
# P = {2, 3, 5, 67, 71, 103} is a primitive set, initial : (2,2344173)[(2, 3)] RRRLLRRLLRRRRLRL  cycle_start : (944701955,1465108491)[(5, 3)] RRLLRRLLRRRRLRL  cycle_end : (529030750625,820458410787)[(5, 3)] (cycle length = 15)
# Now checking: [2, 3, 29, 41, 43, 53]
# P = {2, 3, 29, 41, 43, 53} is a primitive set, initial : (2,3320817)[(2, 3)] RLLRRLLRRLRL  cycle_start : (328761023,521368491)[(29, 3)] LLRRLLRRLRL  cycle_end : (38132957849,60475424139)[(29, 3)] (cycle length = 11)
# Now checking: [2, 3, 5, 101, 257, 337]
# P = {2, 3, 5, 101, 257, 337} is a primitive set, initial : (2,69874593)[(2, 3)] RLRLRRLRLRLLRLLRLRLLRLRLRRLR  cycle_start : (20669743466858,11995161966807)[(2, 3)] RLRLRRLRLRLLRLLRLRLLRLRLRRLR  cycle_end : (7293070945359243002,4232348957974373673)[(2, 3)] (cycle length = 28)
# Now checking: [2, 3, 5, 7, 11, 17, 29]
#   → ❌ [2, 3, 5, 7, 11, 17, 29] は 600 秒を超えたためスキップしました
# Now checking: [2, 3, 7, 11, 13, 17, 31]
# P = {2, 3, 7, 11, 13, 17, 31} is a primitive set, initial : (2,2314779)[(2, 3)] RLLLLRRRLLRLRLLLRRLLLRRLRLRRR  cycle_start : (302747842817,83422378849)[(7, 31)] LLRRRLLRLRLLLRRLLLRRLRLRRR  cycle_end : (19226304503621621,5297821584240253)[(7, 31)] (cycle length = 26)
# Now checking: [2, 3, 5, 7, 11, 29, 67]
#   → ❌ [2, 3, 5, 7, 11, 29, 67] は 600 秒を超えたためスキップしました
# Now checking: [3, 5, 7, 11, 13, 17, 23]
# P = {3, 5, 7, 11, 13, 17, 23} is a primitive set, initial : (3,3759760)[(3, 5)] RRLLLLLRRRLRR  cycle_start : (477489694,172949023)[(11, 13)] LLLRRRLRR  cycle_end : (19092068237,6899162114)[(11, 13)] (cycle length = 9)
# Now checking: [2, 5, 7, 13, 17, 23, 29]
# P = {2, 5, 7, 13, 17, 23, 29} is a primitive set, initial : (184,392075)[(46, 5)] RRRRLRLRRLRRRLLLRRRLLLLLRRLLRRRLLLRRRRRLL  cycle_start : (1365973919216,2989502499929)[(2, 29)] RRLLLRRRLLLLLRRLLRRRLLLRRRRRLL  cycle_end : (49376845420784176,108158750370898509)[(2, 29)] (cycle length = 30)
# Now checking: [2, 5, 7, 11, 13, 29, 41]
# P = {2, 5, 7, 11, 13, 29, 41} is a primitive set, initial : (104,768475)[(26, 5)] RLLRRRLLLLRRLRLLLRRRRLLR  cycle_start : (8974330071,6199104766)[(7, 2)] LRRRLLLLRRLRLLLRRRRLLR  cycle_end : (63340820872539,43753279901374)[(7, 2)] (cycle length = 22)
# Now checking: [2, 3, 7, 13, 19, 23, 53]
# P = {2, 3, 7, 13, 19, 23, 53} is a primitive set, initial : (2,12223461)[(2, 3)] RLRLLLRLRRRLLRRLRRLLLRRLLRL  cycle_start : (614473448856,1050080974157)[(6, 53)] LRRRLLRRLRRLLLRRLLRL  cycle_end : (3186659134638744,5445719797520117)[(6, 53)] (cycle length = 20)
# Now checking: [2, 3, 11, 13, 17, 31, 37]
# P = {2, 3, 11, 13, 17, 31, 37} is a primitive set, initial : (2,8935023)[(2, 3)] RLLRRLLRRRLRRL  cycle_start : (1858485078,2528611909)[(6, 17)] RLLRRRLRRL  cycle_end : (137492155674,187090476193)[(6, 17)] (cycle length = 10)
# Now checking: [2, 5, 7, 11, 19, 29, 41]
# P = {2, 5, 7, 11, 19, 29, 41} is a primitive set, initial : (164,390765)[(82, 5)] RLLRRLLRRRRLLLRLRLL  cycle_start : (342411656,903325727)[(2, 29)] RLLLRLRLL  cycle_end : (16413088394,43352989923)[(2, 29)] (cycle length = 9)
# Now checking: [2, 5, 7, 11, 13, 17, 107]
# P = {2, 5, 7, 11, 13, 17, 107} is a primitive set, initial : (2,3445335)[(2, 5)] RRRRLRRRRLRRRRRLRLLLLRLLLLL  cycle_start : (7004366897,40761763285)[(11, 5)] RLRRRRLRRRRRLRLLLLRLLLLL  cycle_end : (34335396193087,199814160177735)[(11, 5)] (cycle length = 24)
# Now checking: [2, 5, 7, 13, 19, 23, 53]
# P = {2, 5, 7, 13, 19, 23, 53} is a primitive set, initial : (2,20456665)[(2, 5)] RRRRLRLLRRLRLRRRLRRRLRRLRRR  cycle_start : (1354272165196,362471654861)[(2, 19)] RLLRRLRLRRRLRRRLRRLRRR  cycle_end : (11145659837736418,2983141617222703)[(2, 19)] (cycle length = 22)
# Now checking: [2, 3, 7, 11, 17, 37, 73]
# P = {2, 3, 7, 11, 17, 37, 73} is a primitive set, initial : (2,15546165)[(2, 3)] RRLRRRLRRLLLLLLRLLRLLR  cycle_start : (64501041563,47260343782)[(7, 2)] RRLLLLLLRLLRLLR  cycle_end : (16770099798557,12287471737000)[(7, 2)] (cycle length = 15)
# Now checking: [2, 3, 7, 13, 19, 43, 53]
# P = {2, 3, 7, 13, 19, 43, 53} is a primitive set, initial : (2,118515)[(2, 3)] RRLRRRLRLRRLLRRR  cycle_start : (99316172,29036351)[(2, 19)] RRRLRLRRLLRRR  cycle_end : (13308130016,3890515487)[(2, 19)] (cycle length = 13)
# Now checking: [2, 3, 7, 13, 31, 37, 41]
# P = {2, 3, 7, 13, 31, 37, 41} is a primitive set, initial : (2,22322823)[(2, 3)] RLRRLLLRRLLLRLRLLRRRLLRRRL  cycle_start : (753797126882,973208165739)[(2, 3)] RLRRLLLRRLLLRLRLLRRRLLRRRL  cycle_end : (47870640339768290,61804557751098111)[(2, 3)] (cycle length = 26)
# Now checking: [2, 3, 7, 13, 17, 47, 59]
# P = {2, 3, 7, 13, 17, 47, 59} is a primitive set, initial : (2,7744623)[(2, 3)] RLLRRRLLRLRLRRRR  cycle_start : (5181153719,1122970537)[(7, 13)] RRRLLRLRLRRRR  cycle_end : (538832242151,116765701975)[(7, 13)] (cycle length = 13)
# Now checking: [2, 3, 11, 17, 19, 23, 53]
# P = {2, 3, 11, 17, 19, 23, 53} is a primitive set, initial : (2,8620863)[(2, 3)] RLLLLRLRRRRLRRRLRLLLLR  cycle_start : (25250512529,20707316864)[(11, 2)] LLLRLRRRRLRRRLRLLLLR  cycle_end : (58227673271009,47751055446656)[(11, 2)] (cycle length = 20)
# Now checking: [2, 3, 7, 11, 17, 31, 107]
# P = {2, 3, 7, 11, 17, 31, 107} is a primitive set, initial : (68,1484079)[(34, 3)] RRRLLRRRRLLRRRRLRRLLLLLRRLLLLRLLR  cycle_start : (383347149845,282909285349)[(11, 31)] RRRRLLRRRRLRRLLLLLRRLLLLRLLR  cycle_end : (3258008481021239,3620789685463)[(11, 31)] (cycle length = 28)
# Now checking: [2, 3, 7, 11, 17, 59, 61]
# P = {2, 3, 7, 11, 17, 59, 61} is a primitive set, initial : (2,24991629)[(2, 3)] RRRLLLLLRRRL  cycle_start : (1274573111,1674439185)[(7, 3)] RRLLLLLRRRL  cycle_end : (78998541251,103790237841)[(7, 3)] (cycle length = 11)
# Now checking: [2, 5, 7, 13, 17, 37, 53]
# P = {2, 5, 7, 13, 17, 37, 53} is a primitive set, initial : (2,27298885)[(2, 5)] RLLRRRRLRRLRLRLLRRRRLL  cycle_start : (85309019929,190082145845)[(7, 5)] LLRRRRLRRLRLRLLRRRRLL  cycle_end : (368534938794393,821154842751515)[(7, 5)] (cycle length = 21)
# Now checking: [2, 3, 7, 17, 19, 43, 53]
# P = {2, 3, 7, 17, 19, 43, 53} is a primitive set, initial : (2,3755799)[(2, 3)] RRLRRRLRLRRLLRRR  cycle_start : (3147360164,920170931)[(2, 19)] RRRLRLRRLLRRR  cycle_end : (421738750376,123291637355)[(2, 19)] (cycle length = 13)
# Now checking: [2, 3, 7, 11, 23, 29, 103]
# P = {2, 3, 7, 11, 23, 29, 103} is a primitive set, initial : (2,18492213)[(2, 3)] RRRLRLRRLLRRRRRRLLRRLLRRLLLLLLRRL  cycle_start : (3496822105813,5118792648566)[(23, 2)] LRRLLRRRRRRLLRRLLRRLLLLLLRRL  cycle_end : (339316022513449,63930293177164208)[(23, 2)] (cycle length = 28)
# Now checking: [2, 5, 7, 11, 19, 31, 71]
# P = {2, 5, 7, 11, 19, 31, 71} is a primitive set, initial : (2,14251515)[(2, 5)] RRRLLLLRRLRRLRRRRLLRLLR  cycle_start : (123745910123,90197842355)[(11, 5)] LLLLRRLRRLRRRRLLRLLR  cycle_end : (388314623211427,283040815058475)[(11, 5)] (cycle length = 20)
# Now checking: [2, 3, 11, 13, 19, 43, 53]
# P = {2, 3, 11, 13, 19, 43, 53} is a primitive set, initial : (2,35158935)[(2, 3)] RLLRRRRRRLLRRLR  cycle_start : (8543621537,4992568964)[(11, 2)] LRRRRRRLLRRLR  cycle_end : (1144810127021,668933923304)[(11, 2)] (cycle length = 13)
# Now checking: [2, 5, 7, 17, 23, 31, 47]
# P = {2, 5, 7, 17, 23, 31, 47} is a primitive set, initial : (2,38749555)[(2, 5)] RLLRRLLLRLRRLR  cycle_start : (13058600513,7594913058)[(7, 2)] LRRLLLRLRRLR  cycle_end : (2585564152017,1503715286372)[(7, 2)] (cycle length = 12)
# Now checking: [2, 3, 7, 13, 23, 47, 73]
# P = {2, 3, 7, 13, 23, 47, 73} is a primitive set, initial : (2,33367857)[(2, 3)] RLRRLRRRRLLRLRRRRRLRL  cycle_start : (72775298627,112149371245)[(73, 47)] RRLLRLRRRRRLRL  cycle_end : (20813101418017,32074486601063)[(73, 47)] (cycle length = 14)
# Now checking: [2, 3, 7, 17, 23, 41, 67]
# P = {2, 3, 7, 17, 23, 41, 67} is a primitive set, initial : (2,30495897)[(2, 3)] RRLRLLRRRLRRRRRLLLRLLRLLLLR  cycle_start : (902831053541,745380733344)[(23, 6)] LRRRLRRRRRLLLRLLRLLLLR  cycle_end : (3898424336710549,3218553762612210)[(23, 6)] (cycle length = 22)
# Now checking: [2, 3, 7, 11, 13, 67, 113]
# P = {2, 3, 7, 11, 13, 67, 113} is a primitive set, initial : (2,1477341)[(2, 3)] RRLRRRLRRRLLRLLLRRRLRL  cycle_start : (7119309733,11150975278)[(113, 2)] RLLRLLLRRRLRL  cycle_end : (1850962914253,2899232889496)[(113, 2)] (cycle length = 13)
# Now checking: [2, 3, 11, 17, 19, 43, 53]
# P = {2, 3, 11, 17, 19, 43, 53} is a primitive set, initial : (2,18011739)[(2, 3)] RLLRRRRRRLLRRLR  cycle_start : (4376852909,2557667132)[(11, 2)] LRRRRRRLLRRLR  cycle_end : (586480278065,342691372208)[(11, 2)] (cycle length = 13)
# Now checking: [3, 7, 11, 17, 19, 23, 29]
# P = {3, 7, 11, 17, 19, 23, 29} is a primitive set, initial : (3,18947530)[(3, 7)] RLLRRLRR  cycle_start : (511583367,189475321)[(3, 7)] RLLRRLRR  cycle_end : (14835917640,5475836779)[(3, 7)] (cycle length = 8)
# Now checking: [2, 3, 7, 11, 13, 29, 317]
# P = {2, 3, 7, 11, 13, 29, 317} is a primitive set, initial : (2,50251479)[(2, 3)] RRRLRLLLRRLLLLLLRRLLLLRLLR  cycle_start : (828998658323,611811763659)[(11, 3)] LRLLLRRLLLLLLRRLLLLRLLR  cycle_end : (5433257055894503,4009814248769607)[(11, 3)] (cycle length = 23)
# Now checking: [3, 5, 7, 13, 17, 47, 53]
# P = {3, 5, 7, 13, 17, 47, 53} is a primitive set, initial : (3,18039935)[(3, 5)] LLRLLRLLLLLR  cycle_start : (487078467,414918694)[(3, 17)] RLLRLLLLLR  cycle_end : (20944374078,17823463901)[(3, 17)] (cycle length = 10)
# Now checking: [2, 3, 7, 13, 31, 41, 89]
# P = {2, 3, 7, 13, 31, 41, 89} is a primitive set, initial : (2,46794543)[(2, 3)] RLLLLLLLRRLLR  cycle_start : (2760878141,1965370880)[(7, 2)] LLLLLLRRLLR  cycle_end : (137997112505,98174954912)[(7, 2)] (cycle length = 11)
# Now checking: [2, 7, 11, 13, 17, 31, 59]
# P = {2, 7, 11, 13, 17, 31, 59} is a primitive set, initial : (2,1614655)[(2, 7)] RLLLRLRLLRRLRRRR  cycle_start : (949418062,201832071)[(2, 7)] RLLLRLRLLRRLRRRR  cycle_end : (556358984330,118271978951)[(2, 7)] (cycle length = 16)
# Now checking: [2, 3, 7, 23, 29, 43, 53]
# P = {2, 3, 7, 23, 29, 43, 53} is a primitive set, initial : (2,8586597)[(2, 3)] RRRLRLRRRRRLLLR  cycle_start : (2223928765,1691559717)[(23, 3)] LRLRRRRRLLLR  cycle_end : (235710689297,179296743405)[(23, 3)] (cycle length = 12)
# Now checking: [2, 3, 7, 17, 37, 41, 59]
# P = {2, 3, 7, 17, 37, 41, 59} is a primitive set, initial : (2,58878825)[(2, 3)] RRLRLLRRRRLLLL  cycle_start : (3356093069,14189797011)[(7, 3)] RLRLLRRRRLLLL  cycle_end : (570476942903,2412206613045)[(7, 3)] (cycle length = 13)
# Now checking: [2, 3, 7, 11, 29, 47, 103]
# P = {2, 3, 7, 11, 29, 47, 103} is a primitive set, initial : (2,53475021)[(2, 3)] RLRRLLLRRRRRRRLLRRRLLLLLL  cycle_start : (49143545381,309032153163)[(7, 3)] LRRLLLRRRRRRRLLRRRLLLLLL  cycle_end : (143400811946735,901755769454613)[(7, 3)] (cycle length = 24)
# Now checking: [2, 3, 7, 11, 43, 53, 67]
# P = {2, 3, 7, 11, 43, 53, 67} is a primitive set, initial : (2,44480175)[(2, 3)] RRLRLLRRRRLLRRLRL  cycle_start : (33315651653,52797968641)[(53, 11)] LLRRRRLLRRLRL  cycle_end : (6729539233027,10665056224955)[(53, 11)] (cycle length = 13)
# Now checking: [2, 5, 7, 17, 19, 37, 89]
# P = {2, 5, 7, 17, 19, 37, 89} is a primitive set, initial : (2,40769405)[(2, 5)] RRLRLLLLRRLRLRRRLLLRRRLLRLRLLLRRR  cycle_start : (33747079484679,10302754996846)[(19, 2)] LLLRRLRLRRRLLLRRRLLRLRLLLRRR  cycle_end : (1262525286439074729,1262108092297473446)[(19, 2)] (cycle length = 28)
# Now checking: [2, 5, 7, 19, 23, 43, 59]
# P = {2, 5, 7, 19, 23, 43, 59} is a primitive set, initial : (2,41554665)[(2, 5)] RRLRRLLRLLRRLLLLLRRLRRLLRRR  cycle_start : (2706122942312,790909953027)[(2, 19)] RRLLRLLRRLLLLLRRLRRLLRRR  cycle_end : (32749499764750492,9571592126868757)[(2, 19)] (cycle length = 24)
# Now checking: [3, 5, 11, 13, 23, 37, 47]
# P = {3, 5, 11, 13, 23, 37, 47} is a primitive set, initial : (3,19491590)[(3, 5)] RLLRLLLRRLR  cycle_start : (1617802153,955088018)[(11, 23)] LRLLLRRLR  cycle_end : (84106220363,49625593753)[(11, 23)] (cycle length = 9)
# Now checking: [2, 3, 17, 19, 23, 41, 53]
# P = {2, 3, 17, 19, 23, 41, 53} is a primitive set, initial : (2,91985961)[(2, 3)] RLRRLRLRLLRRRRL  cycle_start : (32655016567,40105879502)[(23, 2)] RLRLRLLRRRRL  cycle_end : (5551076858503,6817815543416)[(23, 2)] (cycle length = 12)
# Now checking: [2, 11, 13, 17, 23, 29, 31]
# P = {2, 11, 13, 17, 23, 29, 31} is a primitive set, initial : (2,36223627)[(2, 11)] RLLRLLLRRLRLRRRLLR  cycle_start : (56834873069,39483755032)[(13, 2)] LRLLLRRLRLRRRLLR  cycle_end : (58312543545165,40510260215576)[(13, 2)] (cycle length = 16)
# Now checking: [2, 3, 17, 19, 31, 41, 43]
# P = {2, 3, 17, 19, 31, 41, 43} is a primitive set, initial : (2,46613301)[(2, 3)] RRLRRLLRLL  cycle_start : (1258559147,3402771027)[(17, 3)] RLRRLLRLL  cycle_end : (70432698929,190508564211)[(17, 3)] (cycle length = 9)
# Now checking: [2, 3, 7, 17, 43, 53, 67]
# P = {2, 3, 7, 17, 43, 53, 67} is a primitive set, initial : (2,25240857)[(2, 3)] RRLRLLRRRRLLRRLRL  cycle_start : (18905402471,29960898175)[(53, 17)] LLRRRRLLRRLRL  cycle_end : (3818765094853,6052025708777)[(53, 17)] (cycle length = 13)
# Now checking: [2, 3, 11, 13, 31, 41, 103]
# P = {2, 3, 11, 13, 31, 41, 103} is a primitive set, initial : (2,51195021)[(2, 3)] RLRLLLRLRRL  cycle_start : (3276481426,4556356983)[(2, 3)] RLRLLLRLRRL  cycle_end : (425942585378,592275212769)[(2, 3)] (cycle length = 11)
# Now checking: [2, 3, 7, 11, 47, 71, 73]
# P = {2, 3, 7, 11, 47, 71, 73} is a primitive set, initial : (2,72738405)[(2, 3)] RLRLRLLRLRLRRL  cycle_start : (24512842903,33896097308)[(47, 2)] LRLLRLRLRRL  cycle_end : (3578656848619,4948684730156)[(47, 2)] (cycle length = 11)
# Now checking: [2, 7, 11, 13, 23, 37, 67]
# P = {2, 7, 11, 13, 23, 37, 67} is a primitive set, initial : (2,62604199)[(2, 7)] RRLRRLRLLLLLRLLRLRRR  cycle_start : (187311765610,52399715179)[(2, 7)] RRLRRLRLLLLLRLLRLRRR  cycle_end : (363010201752178,101550585412703)[(2, 7)] (cycle length = 20)
# Now checking: [2, 3, 7, 11, 17, 113, 137]
# P = {2, 3, 7, 11, 17, 113, 137} is a primitive set, initial : (2,16400403)[(2, 3)] RLLRRRLRLLLLLL  cycle_start : (377209301,2476461063)[(7, 3)] LLRRRLRLLLLLL  cycle_end : (23370576257,153524185503)[(7, 3)] (cycle length = 13)
# Now checking: [2, 3, 11, 13, 31, 67, 79]
# P = {2, 3, 11, 13, 31, 67, 79} is a primitive set, initial : (2,47869149)[(2, 3)] RLLRRRRLLRRRRLLLRLLRLRRLLLLRRRLRRL  cycle_start : (22492852118768,30632187365299)[(2, 13)] RLLRRRRLLLRLLRLRRLLLLRRRLRRL  cycle_end : (794580403544267618,1586912132788158397)[(2, 13)] (cycle length = 28)
# Now checking: [2, 7, 11, 23, 29, 37, 41]
# P = {2, 7, 11, 23, 29, 37, 41} is a primitive set, initial : (2,79926889)[(2, 7)] RLLLRRLLLLR  cycle_start : (3916417637,3197075622)[(11, 2)] LLRRLLLLR  cycle_end : (140911108041,114934868612)[(11, 2)] (cycle length = 9)
# Now checking: [2, 3, 11, 17, 43, 53, 67]
# P = {2, 3, 11, 17, 43, 53, 67} is a primitive set, initial : (2,91753671)[(2, 3)] RLRLLLRRRLRLLRRL  cycle_start : (46702619189,66246151384)[(43, 2)] LLLRRRLRLLRRL  cycle_end : (9433653815161,13381539072224)[(43, 2)] (cycle length = 13)
# Now checking: [2, 7, 11, 19, 31, 37, 53]
# P = {2, 7, 11, 19, 31, 37, 53} is a primitive set, initial : (2,99739801)[(2, 7)] RLLRRLLLLRL  cycle_start : (3790112492,6882046367)[(2, 7)] RLLRRLLLLRL  cycle_end : (363850799230,660576711431)[(2, 7)] (cycle length = 11)
# Now checking: [2, 5, 7, 11, 17, 73, 191]
# P = {2, 5, 7, 11, 17, 73, 191} is a primitive set, initial : (2,112604245)[(2, 5)] RLLRRRRLLRRLLRL  cycle_start : (27250227624,46505553755)[(2, 5)] RLLRRRRLLRRLLRL  cycle_end : (15805132021918,26973108573655)[(2, 5)] (cycle length = 15)
# Now checking: [2, 3, 7, 13, 47, 59, 127]
# P = {2, 3, 7, 13, 47, 59, 127} is a primitive set, initial : (2,91419921)[(2, 3)] RRRLRLRRRRRLRRRRRRLRLLLLLRLLLLL  cycle_start : (640945069973,3747576844017)[(13, 3)] LRLRRRRRLRRRRRRLRLLLLLRLLLLL  cycle_end : (5908231380751349,34545163256728785)[(13, 3)] (cycle length = 28)
# Now checking: [2, 5, 7, 11, 17, 113, 137]
# P = {2, 5, 7, 11, 17, 113, 137} is a primitive set, initial : (2,19626115)[(2, 5)] RRLRRRLLLLLLLLRRRLR  cycle_start : (12933610263,7359793397)[(7, 11)] LLLLLLLLRRRLR  cycle_end : (801667949033,456248312267)[(7, 11)] (cycle length = 13)
# Now checking: [2, 3, 13, 23, 41, 47, 79]
# P = {2, 3, 13, 23, 41, 47, 79} is a primitive set, initial : (2,6251529)[(2, 3)] RLLRRLRRRLRLRLLRLLLRLR  cycle_start : (63884389205,40972530272)[(13, 2)] LRRLRRRLRLRLLRLLLRLR  cycle_end : (388800386450099,249358806732332)[(13, 2)] (cycle length = 20)
# Now checking: [2, 3, 11, 17, 37, 61, 109]
# P = {2, 3, 11, 17, 37, 61, 109} is a primitive set, initial : (2,271526781)[(2, 3)] RLLLLLLRLLRLR  cycle_start : (23079776533,14662446268)[(11, 2)] LLLLLRLLRLR  cycle_end : (1615312830527,1025828185196)[(11, 2)] (cycle length = 11)
# Now checking: [2, 3, 11, 13, 37, 83, 109]
# P = {2, 3, 11, 13, 37, 83, 109} is a primitive set, initial : (2,269016075)[(2, 3)] RLRLLLLRLRRRRRRL  cycle_start : (54610263487,62949761852)[(13, 2)] LLLLRLRRRRRRL  cycle_end : (4040352449809,4657744344896)[(13, 2)] (cycle length = 13)
# Now checking: [2, 3, 13, 17, 41, 73, 79]
# P = {2, 3, 13, 17, 41, 73, 79} is a primitive set, initial : (2,26749539)[(2, 3)] RRLLRLLRLRRRLRLLLRRLRLLLRLRR  cycle_start : (4073473426628,1590500889625)[(2, 41)] RLLRLRRRLRLLLRRLRLLLRLRR  cycle_end : (106912383501779408,41744286215350051)[(2, 41)] (cycle length = 24)
# Now checking: [2, 3, 7, 17, 61, 71, 109]
# P = {2, 3, 7, 17, 61, 71, 109} is a primitive set, initial : (2,323076759)[(2, 3)] RLRLRLLRLRRL  cycle_start : (41676902071,57830740083)[(7, 3)] LRLRLLRLRRL  cycle_end : (6167858429747,8558626455525)[(7, 3)] (cycle length = 11)
# Now checking: [2, 3, 7, 11, 53, 103, 137]
# P = {2, 3, 7, 11, 53, 103, 137} is a primitive set, initial : (2,343052001)[(2, 3)] RLRRLLLLRRLLRLRRLLLLLRRLRRLL  cycle_start : (11812309591181,28022202798351)[(11, 3)] LRLRRLLLLLRRLRRLL  cycle_end : (10820058775973689,25668313406597361)[(11, 3)] (cycle length = 17)
# Now checking: [2, 3, 11, 23, 41, 43, 131]
# P = {2, 3, 11, 23, 41, 43, 131} is a primitive set, initial : (2,115284057)[(2, 3)] RRLLRLLRRRRRRLRRLRRLLLLLL  cycle_start : (170966257781,1088166221979)[(11, 3)] RLLRLLRRRRRRLRRLRRLLLLLL  cycle_end : (1040500529571107,6622579511680137)[(11, 3)] (cycle length = 24)
# Now checking: [2, 3, 7, 11, 13, 97, 683]
# P = {2, 3, 7, 11, 13, 97, 683} is a primitive set, initial : (2,140668743)[(2, 3)] RLRLLLRRLRRRRLLLLRLRRLLLLLL  cycle_start : (572099782979,3656684007509)[(97, 13)] LRRRRLLLLRLRRLLLLLL  cycle_end : (423350322685853,2705944618200473)[(97, 13)] (cycle length = 19)
# Now checking: [2, 3, 7, 23, 71, 73, 97]
# P = {2, 3, 7, 23, 71, 73, 97} is a primitive set, initial : (2,349339233)[(2, 3)] RRLRRRLRLLRRL  cycle_start : (53448902759,75806613717)[(7, 3)] RLRRRLRLLRRL  cycle_end : (10368737796011,14706133721865)[(7, 3)] (cycle length = 12)
# Now checking: [2, 3, 7, 11, 59, 73, 251]
#   → ❌ [2, 3, 7, 11, 59, 73, 251] は 600 秒を超えたためスキップしました
# Now checking: [2, 3, 11, 31, 41, 79, 89]
# P = {2, 3, 11, 31, 41, 79, 89} is a primitive set, initial : (2,385522575)[(2, 3)] RLLRRLLLRRLLR  cycle_start : (72863766943,51660025240)[(11, 2)] LRRLLLRRLLR  cycle_end : (8597538976697,6095111933168)[(11, 2)] (cycle length = 11)
# Now checking: [2, 3, 7, 11, 13, 223, 449]
# P = {2, 3, 7, 11, 13, 223, 449} is a primitive set, initial : (2,20640975)[(2, 3)] RRRLLRRLLRRRRRLLRLLRRLLRRLLLLLRRL  cycle_start : (6427001209055,9368835613413)[(7, 3)] RRLLRRLLRRRRRLLRLLRRLLRRLLLLLRRL  cycle_end : (1134640261175103389,1589988820713913437)[(7, 3)] (cycle length = 32)
# Now checking: [2, 3, 13, 23, 59, 71, 83]
# P = {2, 3, 13, 23, 59, 71, 83} is a primitive set, initial : (2,508399305)[(2, 3)] RLLLLLRLLLLLRR  cycle_start : (45247538297,20844371575)[(13, 23)] LLLRLLLLLRR  cycle_end : (2533353745325,1165759610281)[(13, 23)] (cycle length = 11)
# Now checking: [2, 3, 7, 11, 19, 223, 449]
# P = {2, 3, 7, 11, 19, 223, 449} is a primitive set, initial : (2,159416997)[(2, 3)] RRRLLRRLLRRRRRLLRLLRRLLRRLLLLLRRL  cycle_start : (49637829955217,72358578119103)[(7, 3)] RRLLRRLLRRRRRLLRLLRRLLRRLLLLLRRL  cycle_end : (8689453223700605447,12169386812685868737)[(7, 3)] (cycle length = 32)
# Now checking: [2, 3, 19, 29, 43, 67, 101]
# P = {2, 3, 19, 29, 43, 67, 101} is a primitive set, initial : (2,294913191)[(2, 3)] RLLRRLLRLLRRRRL  cycle_start : (83755346646,102924704153)[(6, 43)] RLLRLLRRRRL  cycle_end : (7871822931954,9674037450805)[(6, 43)] (cycle length = 11)
# Now checking: [2, 5, 19, 37, 41, 43, 79]
# P = {2, 5, 19, 37, 41, 43, 79} is a primitive set, initial : (2,577445395)[(2, 5)] RLLRRLLRLRLLLRLRRLRLRRRL  cycle_start : (10904478865906,13906617481869)[(2, 37)] RLLRLRLLLRLRRLRLRRRL  cycle_end : (69810471389748626,89030163386589149)[(2, 37)] (cycle length = 20)
# Now checking: [2, 3, 7, 17, 53, 151, 173]
# P = {2, 3, 7, 17, 53, 151, 173} is a primitive set, initial : (2,476031813)[(2, 3)] RRLRRRRRLLLLLLRLRLRLLLLLRRRRRRLRL  cycle_start : (33066597875381,50837817544611)[(7, 3)] RLRRRRRLLLLLLRLRLRLLLLLRRRRRRLRL  cycle_end : (1213971635187277631,1936873874478828057)[(7, 3)] (cycle length = 32)
# Now checking: [2, 3, 7, 13, 19, 241, 409]
# P = {2, 3, 7, 13, 19, 241, 409} is a primitive set, initial : (2,831236817)[(2, 3)] RRLRRRLLRLRRRLRLRLRR  cycle_start : (4482028921154,1709854134053)[(2, 13)] RRRLLRLRRRLRLRLRR  cycle_end : (4553739721418828,1737209306487395)[(2, 13)] (cycle length = 17)
# Now checking: [2, 3, 7, 29, 31, 149, 199]
# P = {2, 3, 7, 29, 31, 149, 199} is a primitive set, initial : (2,320698887)[(2, 3)] RRRRLRRRRLLRLLLL  cycle_start : (24693814331,115772298357)[(29, 3)] RLRRRRLLRLLLL  cycle_end : (3752497681649,17597068651377)[(29, 3)] (cycle length = 13)
# Now checking: [2, 3, 11, 37, 43, 109, 113]
# P = {2, 3, 11, 37, 43, 109, 113} is a primitive set, initial : (2,849582171)[(2, 3)] RLLRRRLLLRRLRRRLLLRRRLLRL  cycle_start : (12224637878585,20747646232047)[(11, 3)] LLRRRLLLRRLRRRLLLRRRLLRL  cycle_end : (213026538822640037,361548482390068851)[(11, 3)] (cycle length = 24)
# Now checking: [2, 5, 11, 17, 47, 103, 149]
# P = {2, 5, 11, 17, 47, 103, 149} is a primitive set, initial : (2,110602435)[(2, 5)] RLLRRRRLLLLRRRRLLRLRLRRL  cycle_start : (955273243031,1320703692837)[(149, 47)] RRRRLLRLRLRRL  cycle_end : (229264140495767,316962803146879)[(149, 47)] (cycle length = 13)
# Now checking: [2, 5, 7, 11, 13, 293, 461]
# P = {2, 5, 7, 11, 13, 293, 461} is a primitive set, initial : (2,813252655)[(2, 5)] RLLRLRRRLLRRRRLRR  cycle_start : (709969569071,252108323496)[(7, 2)] LRLRRRLLRRRRLRR  cycle_end : (333684884210713,118489285537808)[(7, 2)] (cycle length = 15)
# Now checking: [2, 3, 19, 41, 53, 73, 79]
# P = {2, 3, 19, 41, 53, 73, 79} is a primitive set, initial : (2,381152139)[(2, 3)] RLLLLRLRRRLRLLLRRLRLLLRLRRR  cycle_start : (19574068182587,5496595020175)[(19, 41)] LLRLRRRLRLLLRRLRLLLRLRRR  cycle_end : (513740993139026261,144263631756056629)[(19, 41)] (cycle length = 24)
# Now checking: [2, 3, 11, 37, 47, 59, 227]
# P = {2, 3, 11, 37, 47, 59, 227} is a primitive set, initial : (2,391780629)[(2, 3)] RRRLLLLRRRLRRLLR  cycle_start : (200199901735,140649246033)[(37, 3)] LLLLRRRLRRLLR  cycle_end : (36835606577351,25879069489443)[(37, 3)] (cycle length = 13)
# Now checking: [2, 3, 13, 37, 47, 59, 227]
# P = {2, 3, 13, 37, 47, 59, 227} is a primitive set, initial : (2,950750877)[(2, 3)] RRRLLLLRRRLRRLLR  cycle_start : (485833698463,341319565065)[(37, 3)] LLLLRRRLRRLLR  cycle_end : (89390548264559,62801849221083)[(37, 3)] (cycle length = 13)
# Now checking: [2, 3, 7, 29, 53, 103, 283]
# P = {2, 3, 7, 29, 53, 103, 283} is a primitive set, initial : (2,1057070565)[(2, 3)] RLRLLRLLLLLRL  cycle_start : (78223221904,144818667579)[(2, 3)] RLRLLRLLLLLRL  cycle_end : (14393072830334,26645577763971)[(2, 3)] (cycle length = 13)
# Now checking: [2, 3, 7, 19, 113, 137, 197]
# P = {2, 3, 7, 19, 113, 137, 197} is a primitive set, initial : (2,499244373)[(2, 3)] RRRRLLRLLLRLLLLL  cycle_start : (30453906781,176233263831)[(19, 3)] RLLRLLLRLLLLL  cycle_end : (3774786707723,21852425470671)[(19, 3)] (cycle length = 13)
# Now checking: [2, 13, 29, 37, 41, 43, 53]
# P = {2, 13, 29, 37, 41, 43, 53} is a primitive set, initial : (2,2565897217)[(2, 13)] RLLRRLLLRLR  cycle_start : (220667160784,141124347013)[(2, 13)] RLLRRLLLRLR  cycle_end : (25597390650942,16367858356291)[(2, 13)] (cycle length = 11)
# Now checking: [2, 3, 11, 29, 53, 103, 283]
# P = {2, 3, 11, 29, 53, 103, 283} is a primitive set, initial : (2,197840619)[(2, 3)] RRRLRRLRLRRLRRRRRL  cycle_start : (168758048465,198236300776)[(103, 2)] RLRLRRLRRRRRL  cycle_end : (31050096033223,36474687980306)[(103, 2)] (cycle length = 13)
# Now checking: [2, 3, 7, 59, 61, 149, 181]
# P = {2, 3, 7, 59, 61, 149, 181} is a primitive set, initial : (2,379485069)[(2, 3)] RRRLRLRRLLLLLRLRLRLLRRRRRLR  cycle_start : (16306093953551,8846176456311)[(59, 3)] LRLRRLLLLLRLRLRLLRRRRRLR  cycle_end : (258908158656027569,140459589393820989)[(59, 3)] (cycle length = 24)
# Now checking: [2, 3, 7, 71, 73, 97, 241]
# P = {2, 3, 7, 71, 73, 97, 241} is a primitive set, initial : (2,2593448121)[(2, 3)] RRLRRRLLLRLRRRRLL  cycle_start : (982916838133,2181089870369)[(73, 71)] RRLLLRLRRRRLL  cycle_end : (190672899357193,423123654507221)[(73, 71)] (cycle length = 13)
# Now checking: [2, 5, 7, 23, 53, 131, 937]
# P = {2, 5, 7, 23, 53, 131, 937} is a primitive set, initial : (2,3129138675)[(2, 5)] RLLRRRRLRLRRLLRRRLRLLR  cycle_start : (24745228652798,17801669929915)[(2, 5)] RLLRRRRLRLRRLLRRRLRLLR  cycle_end : (275612356734864122,198274996550254595)[(2, 5)] (cycle length = 22)
# Now checking: [2, 3, 31, 43, 71, 109, 191]
# P = {2, 3, 31, 43, 71, 109, 191} is a primitive set, initial : (2,2553820701)[(2, 3)] RLRLLRLRRLRRLRLRRLRLLRLL  cycle_start : (39594436167914,107722711042233)[(2, 3)] RLRLLRLRRLRRLRLRRLRLLRLL  cycle_end : (2058356358625177202,5600072853687704037)[(2, 3)] (cycle length = 24)
# Now checking: [2, 3, 29, 43, 67, 113, 223]
# P = {2, 3, 29, 43, 67, 113, 223} is a primitive set, initial : (2,1786154223)[(2, 3)] RLRLLRLRLLRRRRRL  cycle_start : (759115545313,900221729030)[(43, 2)] LLRLRLLRRRRRL  cycle_end : (124489590968659,147632791252472)[(43, 2)] (cycle length = 13)
