# %%
from function.function3 import check_loop
from function.candidates_primitive_sets import cand_primitive_set

pairs = cand_primitive_set()
limit = 100
for pair in pairs:
    print(check_loop(pair, limit))
