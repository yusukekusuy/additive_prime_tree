# %% [markdown]
# # Find candidates of primitive sets.

# %%
from function.function1 import run_tree_search
from function.primitive_sets import p5, p6, p7, p8, p9, p10

# ===== input =====
P_num = 6
limit = 1000
infinite_pair = p5()
remove_pair = [[3],[5], [7,13]]
need_pair = [[2,11], [17]]

# =================


result = run_tree_search(
    P_num=P_num,
    limit=limit,
    infinite_pair=infinite_pair,
    remove_pair=remove_pair,
    need_pair=need_pair,
    print_path=False,
    verbose=True,
)

new_inf = result["newly_found_infinite_sigs"]
# Out:
# ==== Exploring pair 1 ====
# ==== Exploring pair 2 ====
# ==== Exploring pair 3 ====
# ==== Exploring pair 4 ====
# ==== Exploring pair 5 ====
# ==== Exploring pair 6 ====
# ==== Exploring pair 7 ====
# ==== Exploring pair 8 ====
# ==== Exploring pair 9 ====
#
# ===== Summary =====
# P_num          = 6
# P_set          = ['a', 'b', 'c', 'd', 'e', 'f']
# limit          = 1000
# total leaf cnt = 6393
# elapsed        = 0.134 sec
#
# ===== Deepest finite leaf (did not hit limit) =====
# set  = [2, 7, 11, 19, 29, 41]
# depth  = 23
# cor    = {'a': 2, 'b': 19, 'c': 11, 'd': 7, 'e': 29, 'f': 41}
# pair   = {(1, 0): ['a'], (0, 1): ['b'], (1, 1): ['c'], (1, 2): ['d'], (1, 3): ['e'], (1, 5): ['f']}

# %% [markdown]
# # Check whether P is of finite type or not.

# %%
from function.function3 import check_loop

P = [2,3,5,7,19]
limit = 1000
check_loop(P,limit)
# Out:
# 'P = {2, 3, 5, 7, 19} is a primitive set, initial : (2,3273)[(2, 3)] RRRLLRRRLR  cycle_start : (180047,101481)[(7, 3)] LLRRRLR  cycle_end : (3591119,2026347)[(7, 3)] (cycle length = 7)'
