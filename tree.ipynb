# %% [markdown]
# # Find candidates of primitive sets.

# %%
from function.function1 import run_tree_search
from function.primitive_sets import p5, p6, p7, p8, p9, p10

# ===== input =====
P_num = 5
limit = 1000
infinite_pair = []
remove_pair = []
need_pair = []

# =================


result = run_tree_search(
    P_num=P_num,
    limit=limit,
    infinite_pair=infinite_pair,
    remove_pair=remove_pair,
    need_pair=need_pair,
    print_path=False,
    verbose=True,
)

new_inf = result["newly_found_infinite_sigs"]
# Out:
# ==== Exploring pair 1 ====
# === primitive_set candidate ===
#   vals      : [2, 3, 5, 7, 19]
# === primitive_set candidate ===
#   vals      : [2, 3, 5, 13, 17]
# ==== Exploring pair 2 ====
# ==== Exploring pair 3 ====
# ==== Exploring pair 4 ====
# ==== Exploring pair 5 ====
# ==== Exploring pair 6 ====
#
# ===== Summary =====
# P_num          = 5
# P_set          = ['a', 'b', 'c', 'd', 'e']
# limit          = 1000
# total leaf cnt = 35091
# elapsed        = 0.348 sec
#
# ===== Newly found infinite-type signatures (hit limit) =====
# [2, 3, 5, 7, 19]
# [2, 3, 5, 13, 17]
#
# ===== Deepest finite leaf (did not hit limit) =====
# set  = [2, 3, 5, 11, 37]
# depth  = 26
# cor    = {'a': 2, 'b': 5, 'c': 37, 'd': 3, 'e': 11}
# pair   = {(1, 0): ['a', 'b'], (0, 1): ['c'], (1, 1): ['d'], (1, 3): ['e']}

# %% [markdown]
# # Check whether P is of finite type or not.

# %%
from function.function3 import check_loop

pair = [2, 3, 5, 7, 19]
limit = 10
check_loop(pair, limit)
# Out:
# 'P = {2, 3, 5, 7, 19}: inconclusive (no cycle detected on the deepest path).'
