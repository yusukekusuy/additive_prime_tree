# %% [markdown]
# # Find candidates of primitive sets.

# %%
from function.function1 import run_tree_search
from function.primitive_sets import p5, p6, p7, p8, p9, p10

# ===== input =====
P_num = 8
limit = 1000
infinite_pair = p5() + p6() + p7()
remove_pair = [[3], [5]]
need_pair = []

# =================


result = run_tree_search(
    P_num=P_num,
    limit=limit,
    infinite_pair=infinite_pair,
    remove_pair=remove_pair,
    need_pair=need_pair,
    print_path=False,
    verbose=True,
)

new_inf = result["newly_found_infinite_sigs"]
# Out:
# ==== Exploring pair 1 ====
# === primitive_set candidate ===
#   vals      : [2, 3, 5, 7, 11, 29, 67]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 14
#       9 need_pair = []
#      11 # =================
# ---> 14 result = run_tree_search(
#      15     P_num=P_num,
#      16     limit=limit,
#      17     infinite_pair=infinite_pair,
#      18     remove_pair=remove_pair,
#      19     need_pair=need_pair,
#      20     print_path=False,
#      21     verbose=True,
#      22 )
#      24 new_inf = result["newly_found_infinite_sigs"]
#
# File ~/Desktop/additive_prime_tree/function/function1.py:311, in run_tree_search(P_num, limit, infinite_pair, remove_pair, need_pair, print_path, verbose)
#     307 known_inf = [tuple(sorted(sig)) for sig in infinite_pair]
#     309 t0 = time.perf_counter()
# --> 311 infinite_pair, total_leaf_count, best_cor, best_pairing, best_path = tree_all_dfs(
#     312     P_set=P_set,
#     313     infinite_pair=infinite_pair,
#     314     remove_pair=remove_pair,
#     315     need_pair=need_pair,
#     316     limit=limit,
#     317     print_path=print_path,
#     318 )
#     320 t1 = time.perf_counter()
#     321 elapsed = t1 - t0
#
# File ~/Desktop/additive_prime_tree/function/function1.py:261, in tree_all_dfs(P_set, infinite_pair, remove_pair, need_pair, limit, print_path)
#     253 for m, (cor, pairing, path) in enumerate(first_pair):
#     254     print(f"==== Exploring pair {m + 1} ====")
#     256     (results,
#     257      leaf_count,
#     258      best_cor_i,
#     259      best_pairing_i,
#     260      best_path_i,
# --> 261      hit_limit_i) = dfs_explore(
#     262         P_set, cor, pairing, path,
#     263         infinite_pair, remove_pair, need_pair, limit
#     264     )
#     266     total_leaf_count += leaf_count
#     268     if hit_limit_i:
#
# File ~/Desktop/additive_prime_tree/function/function1.py:196, in dfs_explore(P_set, cor, pairing, path, infinite_pair, remove_pair, need_pair, limit)
#     193         print("  vals      :", sorted(key))
#     194     continue
# --> 196 next_states = create_new_path(P_set, cor_cur, pairing_cur, path_cur)
#     198 any_child = False
#     200 for cor_new, pairing_new, path_new, valid in next_states:
#
# File ~/Desktop/additive_prime_tree/function/function1.py:144, in create_new_path(P_set, cor, pairing, path)
#     143 def create_new_path(P_set, cor, pairing, path):
# --> 144     div, res1 = divide_check(P_set, cor, pairing, path)
#     145     if div >= 1:
#     146         return res1
#
# File ~/Desktop/additive_prime_tree/function/function1.py:55, in divide_check(P_set, cor, pairing, path)
#      53 result = []
#      54 last_path = path[-1]
# ---> 55 new_element = tuple(a + b for a, b in zip(last_path[0], last_path[1]))
#      56 if len(path) % 30 == 0 and all(cor[p] > 1 for p in P_set):
#      57     N_P = prod(cor[p] for p in P_set)
#
# File ~/Desktop/additive_prime_tree/function/function1.py:55, in <genexpr>(.0)
#      53 result = []
#      54 last_path = path[-1]
# ---> 55 new_element = tuple(a + b for a, b in zip(last_path[0], last_path[1]))
#      56 if len(path) % 30 == 0 and all(cor[p] > 1 for p in P_set):
#      57     N_P = prod(cor[p] for p in P_set)
#
# KeyboardInterrupt:

# %% [markdown]
# # Check whether P is of finite type or not.

# %%
from function.function3 import check_loop

pair = [2, 3, 5, 7, 19]
limit = 100
check_loop(pair, limit)
# Out:
# 'P = {2, 3, 5, 7, 19} is a primitive set, initial : (2,3273)[(2, 3)] RRRLLRRRLR  cycle_start : (180047,101481)[(7, 3)] LLRRRLR  cycle_end : (3591119,2026347)[(7, 3)] (cycle length = 7)'
